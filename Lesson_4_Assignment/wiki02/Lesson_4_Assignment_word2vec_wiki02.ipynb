# %%
import pandas as pd
import jieba
from gensim.models import word2vec
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
corpus = []
with open('C:\\Users\\ywan3\\Desktop\\NLP\\Data\\text\\01\\wiki_02simple', 'r') as f:
    lines = f.readlines()
    for i, line in enumerate(lines):
        if i % 10000 == 0:
            print(i)
        if i % 3000000 == 0 and i != 0:
            break
        words = list(jieba.cut(line))
        corpus.append(words)
print(corpus[:2])
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\ywan3\AppData\Local\Temp\jieba.cache
# 0
# Loading model cost 0.778 seconds.
# Prefix dict has been built succesfully.
# [['\n'], ['山西省', '\n']]

# %%
model = word2vec.Word2Vec(corpus, size=100, window=20, min_count=5, workers=8)
# Out:
# C:\Users\ywan3\Anaconda3\envs\py35_64\lib\site-packages\gensim\models\base_any2vec.py:743: UserWarning: C extension not loaded, training will be slow. Install a C compiler and reinstall gensim for fast training.
#   "C extension not loaded, training will be slow. "

# %%
model.wv['山西']
# Out:
# array([ 0.18263184,  0.11387474,  0.03298657,  0.3409411 , -0.3776219 ,
#         0.265004  , -0.0791434 ,  0.22812058,  0.24196868, -0.25284174,
#         0.00887974,  0.4474475 , -0.2760657 , -0.04873212,  0.5985879 ,
#        -0.16822052,  0.17573442, -0.12034058,  0.08083384, -0.42646   ,
#         0.05879815,  0.24993241,  0.40813464, -0.06219371,  0.21960673,
#        -0.24646975, -0.09459834, -0.36478385,  0.05160826,  0.1240531 ,
#         0.31574392, -0.00691329, -0.2761596 , -0.66051424, -0.28556404,
#        -0.32345363,  0.02874307,  0.21572037,  0.16788039, -0.4602578 ,
#        -0.12331784,  0.01692691,  0.369092  ,  0.474147  ,  0.30996102,
#        -0.13659789,  0.13685697, -0.15407397, -0.26968557, -0.43970162,
#        -0.08902197,  0.21278895, -0.17372699,  0.09852294, -0.1791271 ,
#         0.57240754,  0.10770163, -0.30937955, -0.01743778,  0.06155394,
#         0.0119088 ,  0.52841026,  0.05669653, -0.18650289, -0.3754332 ,
# ...

# %%
def tsne_plot(model):
    "Creates and TSNE model and plots it"
    labels = []
    tokens = []

    for word in model.wv.vocab:
        tokens.append(model[word])
        labels.append(word)
    
    tsne_model = TSNE(perplexity=40, n_components=2, init='pca', n_iter=2500, random_state=23)
    new_values = tsne_model.fit_transform(tokens)

    x = []
    y = []
    for value in new_values:
        x.append(value[0])
        y.append(value[1])
        
    plt.figure(figsize=(16, 16)) 
    for i in range(len(x)):
        plt.scatter(x[i],y[i])
        plt.annotate(labels[i],
                     xy=(x[i], y[i]),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')
    plt.show()

# %%
import matplotlib
matplotlib.rcParams['font.family'] = 'Arial Unicode MS'
matplotlib.rcParams['font.serif'] = 'Arial Unicode MS'
matplotlib.rcParams['font.sans-serif'] = 'Arial Unicode MS'
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
tsne_plot(model)
# Out:
# C:\Users\ywan3\Anaconda3\envs\py35_64\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   import sys
# findfont: Font family ['Arial Unicode MS'] not found. Falling back to DejaVu Sans.
# C:\Users\ywan3\Anaconda3\envs\py35_64\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 23665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ywan3\Anaconda3\envs\py35_64\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 35199 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ywan3\Anaconda3\envs\py35_64\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 30465 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
model.wv.most_similar('四川')
# Out:
# [('市区', 0.9805678129196167),
#  ('沈阳', 0.9802420735359192),
#  ('主体', 0.9786769151687622),
#  ('渤海', 0.9774320721626282),
#  ('5A', 0.97712641954422),
#  ('山区', 0.9767888188362122),
#  ('西站', 0.9753257036209106),
#  ('分行', 0.975203275680542),
#  ('位于', 0.9746906757354736),
#  ('客运', 0.9738405346870422)]

# %%
model.wv.most_similar('云南')
# Out:
# [('研究生', 0.995252251625061),
#  ('防城港', 0.9951314330101013),
#  ('广东', 0.9940356612205505),
#  ('白', 0.9936309456825256),
#  ('深圳河', 0.9929947853088379),
#  ('南山', 0.9929422736167908),
#  ('嘉陵江', 0.992906928062439),
#  ('电视网', 0.9928731322288513),
#  ('调', 0.9923499822616577),
#  ('北', 0.9921900629997253)]
